# %%
from maze import maze, solve_maze, show_resulting
import zot_constants as CC
import numpy as np
from tqdm.notebook import trange

maxSolves = 50
noBarTF = True
mymaze = maze(height=25,width=25,scoreType='best')

Tdur = np.zeros(maxSolves)
bestScores= []

for thisSolve in trange(maxSolves):
    Tdur[thisSolve], bestZot, bestList  = solve_maze(mymaze,noBar=noBarTF)
    bestScores.append(bestList)

show_resulting(mymaze,bestZot,bestList,Tdur,bestScores)
# Out:
# (25, 25)
# [23, 24]
# Solved in 46 cycles.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Duration: 9.0 +/- 4.0

# %%
from maze import maze, solve_maze,show_resulting
import zot_constants as CC
import numpy as np
from tqdm.notebook import trange

maxSolves = 50
noBarTF = True
mymaze = maze(height=25,width=25,scoreType='best',
              number_of_mutations_per_parent=int(CC.dna_length*0.5))

Tdur = np.zeros(maxSolves)
bestScores= []

for thisSolve in trange(maxSolves):
    Tdur[thisSolve], bestZot, bestList  = solve_maze(mymaze,noBar=noBarTF)
    bestScores.append(bestList)
# this is with 25% mutation rate of every parent

show_resulting(mymaze,bestZot,bestList,Tdur,bestScores)
# Out:
# (25, 25)
# [23, 24]
# Solved in 52 cycles.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Duration: 11.0 +/- 4.0

# %%
from maze import maze, solve_maze,show_resulting
import zot_constants as CC
import numpy as np
from tqdm.notebook import trange

maxSolves = 50
noBarTF = True
mymaze = maze(height=25,width=25,scoreType='best',
              number_of_mutations_per_parent=int(CC.dna_length*0.9))

Tdur = np.zeros(maxSolves)
bestScores= []

for thisSolve in trange(maxSolves):
    Tdur[thisSolve], bestZot, bestList  = solve_maze(mymaze,noBar=noBarTF)
    bestScores.append(bestList)
# this is with 25% mutation rate of every parent

show_resulting(mymaze,bestZot,bestList,Tdur,bestScores)
# Out:
# (25, 25)
# [23, 24]
# Solved in 46 cycles.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Duration: 7.0 +/- 2.0

# %%
from zot import figure_out_value_of_population_rule

this_rule=1.2
figure_out_value_of_population_rule(this_rule)
# Out:
# 0.03

# %%
import numpy as np

x = np.array([4,5,3,1,5])
x[np.argsort(x)]
# Out:
# array([1, 3, 4, 5, 5])
